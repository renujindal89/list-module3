# %%
#text or collection of items
#creating string
#access(indexing an slicing)
#adding char
#editing string
#deleting
#operation
#functions

# %%
#string is immutable datatype
#we can not manipulate it 
#however we can create a copy of that string and then make the necessary changes

# %%
s='hello'
print(s)
type(s)
# Out:
# hello
# str

# %%
s="hello,it's"
print(s)
s1="hello,it's raining outside"
print(s1)
s2="""hello
hru"""
print(s2)
# Out:
# hello,it's
# hello,it's raining outside
# hello
# hru

# %% [markdown]
# # indexing

# %%
s='hello world'
print(s[-6])
s[-1]
s[-3]
# Out:
# 'r'

# %% [markdown]
# # slicing

# %%
s='hello world'
print(s[-1:-6:1])

# %%
s[0:1]
print(s[-1:-6:-1])
print(s[6:0:-1])
s[:-1]
s[::-1]
s[:-2]
# Out:
# dlrow
# w olle
# 'hello wor'

# %%
s='hello world'
s[::-1]
s[-1:-6:-1]
# Out:
# 'dlrow'

# %%
#reverse the string
s[::-1]
# Out:
# 'dlrow olleh'

# %%
#concate the string
print("hello" + " "+ "world")
# Out:
# hello world

# %%
s='hello'
s1='world'
a=s+s1
print(s)
print(a)
# Out:
# hello
# helloworld

# %% [markdown]
# # editing/deleting

# %%
s='hello world' # does not support
s[1]='H'
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 s='hello world' # does not support
# ----> 2 s[1]='H'
#       3 s
#
# TypeError: 'str' object does not support item assignment

# %%
s='hello world'
l=list(s)
l
# Out:
# ['h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd']

# %%
del s[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 del s[-1]
#
# TypeError: 'str' object doesn't support item deletion

# %%
del s

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s
#
# NameError: name 's' is not defined

# %% [markdown]
# # operation +,*

# %%
print('delhi'+""+'mumbai')
# Out:
# delhi mumbai

# %%
#repeat the string

# %%
print('delhi' * 3)
# Out:
# delhidelhidelhi

# %%
==,=

# %%
print('Delhi'=='DElhi')
# Out:
# False

# %%
In Python, all lowercase letters ('a'–'z') have higher Unicode values than
uppercase letters ('A'–'Z').

# %%
print('mumbai'>'Pune')
#'m' → Unicode 109
#'p' → Unicode 112
# Out:
# True

# %%
print('mumbai'>'Pune')

# %% [markdown]
# # loop

# %%
for i in 'hello':
    print(i)
# Out:
# h
# e
# l
# l
# o

# %% [markdown]
# # Membership

# %%
print('a' in 'delhi')
# Out:
# False

# %%
print('D' in 'delhi')
# Out:
# False

# %%
'd' not in 'delhi'
# Out:
# False

# %%
# Membership 
String = "John! Did you attend the conference on advanced machine learning"
print( 'a' in String)
print ( 'Behzad' not in String)
# Out:
# True
# True

# %% [markdown]
# # functions

# %%
s = "i am upper cased"
length=len(s)
print(length)
# Out:
# 16

# %%
s = "i am upper cased"
s.capitalize()
# Out:
# 'I am upper cased'

# %%
s = "i am upper cased"
s.title()
# Out:
# 'I Am Upper Cased'

# %%
# upper() 
small = "i am upper cased"
print(small.upper())
# Out:
# I AM UPPER CASED

# %%
 #lower() 
large = "I AM LOWER CASED"
print(large.lower())
# Out:
# i am lower cased

# %%
# rstrip () function
some_sentence = "    There is a space at the end    "
print(len(some_sentence))
print(len((some_sentence.rstrip())))
# Out:
# 35
# 31

# %%
increment = '4%%%%%%%%@@@@@@'
print(increment.rstrip('%@'))
# Out:
# 4

# %%
# lstrip() function
start = "   There is space at the start"
print(start)
print(start.lstrip())
# Out:
#    There is space at the start
# There is space at the start

# %%
# strip() function 
spaces = "   Trim whitespaces  "
print(spaces)
print(spaces.strip())
# Out:
#    Trim whitespaces
# Trim whitespaces

# %%
#strip specific character

# %%
num_with_chars = '******444#######'
print(num_with_chars.rstrip('#').lstrip('*'))
# Out:
# 444

# %%
#count() Method
#count the occurance
#string.count(substring, start, end)
string = "this is a sample sentence"
print(string.count('a')) # count the occurance of character
print(string.count('t'))
# Out:
# 2
# 2

# %%
s = "banana"
print(s.count('a', 2, 5)) # exclude 5
# Out:
# 1

# %%
text = "APPLE apple APPLE"
print(text.count("APPLE"))
# Out:
# 2

# %%
text = "Apple apple APPLE"
print(text.lower().count("apple"))

# %%
# When you want to safely check presence
# fails safely (-1)
s = "This is a sample sentence"
s.find('s') # first accurance
# Out:
# 3

# %%
s = "This is a sample sentence"
s.find('q') # first accurance
s.find('is')
# Out:
# 2

# %%
s.index('s')
print("hello")
# Out:
# hello

# %%
# use when substring must exist
#interrupts (ValueError)
s.index('is')
s.index('q')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 4
#       1 # use when substring must exist
#       2 #interrupts (ValueError)
#       3 s.index('is')
# ----> 4 s.index('q')
#
# ValueError: substring not found

# %% [markdown]
# # format function

# %%
"string with placeholders {}".format(values)
{} → placeholder
values → values to insert into placeholders

# %%
print("my name is",name,"and i am ",age,"years old")

# %%
name='renu'
age = 36
print("My name is {} and I am {} years old.".format(name, age))
# Out:
# My name is renu and I am 36 years old.

# %%
name='renu'
age = 36
print(f"my name is {name}, and my age is {age}")
# Out:
# my name is renu, and my age is 36

# %%
name=input("enter name")
age=input("enter age")
print(f"my name is {name} and age is {age}")
# Out:
# enter name renu
# enter age 36
# my name is renu and age is 36

# %%
name='renu'
greeting=f"hello,{name}!"
print(greeting)

# %% [markdown]
# # split/join

# %%
#split to convert string into list

# %%
#string.split(separator, maxsplit)
s='renugoel89@gmail.com'
print(s.split( )) #by space
#s.split('i') # by character
l1=s.split('@') #by special character
# Out:
# ['renugoel89@gmail.com']

# %%
text = "onetwo three four five"
parts = text.split(maxsplit=1)
print(parts)
# Out:
# ['onetwo', 'three four five']

# %%
text = "onetwo three four five"
parts = text.split()
print(parts)
# Out:
# ['onetwo', 'three', 'four', 'five']

# %%
data = "apple,banana,cherry,date,elderberry"
parts = data.split(",", maxsplit=3)
print(parts)

# %%
text = "a b c d"
print(text.split(maxsplit=0))  # No split
print(text.split())            # Split all
# Out:
# ['a b c d']
# ['a', 'b', 'c', 'd']

# %% [markdown]
# # join (list ---> string)

# %%
s=['hi','my','name','is','renu']
" @ ".join (s)
# Out:
# 'hi @ my @ name @ is @ renu'

# %%
s='real world'
s.replace('r','R')
# Out:
# 'Real woRld'

# %%
s1=s.replace('real','R')
s1
# Out:
# 'R world'

# %%
s
# Out:
# 'real world'

# %%
s1
# Out:
# 'R world'

# %%
text = "Hello world"
print(text.startswith("e"))
# Out:
# False

# %%
text = "Hello world"
print(text.startswith("hello"))

# %%
text = "hello world"
print(text.endswith("D"))
# Out:
# False

# %%
#contain
text = "Hello world"
print("wor" in text)
# Out:
# True
